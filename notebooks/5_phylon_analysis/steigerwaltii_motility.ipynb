# %%
# Base imports
import os
import pickle
import re

# Compute imports
import numpy as np
import pandas as pd
import scipy
from tqdm.notebook import tqdm, trange

# Plotting imports
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
from plotly import express as px
import matplotlib.patches as mpatches

# ML import
from sklearn.decomposition import NMF
from sklearn.metrics import mean_squared_error, median_absolute_error
from sklearn.metrics.pairwise import cosine_similarity

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['svg.fonttype'] = 'none'
matplotlib.rcParams['font.sans-serif'] = 'Arial'
matplotlib.rcParams['font.family'] = 'sans-serif'
sns.set_style('ticks')
matplotlib.rcParams['text.color'] = '#000000'
matplotlib.rcParams['axes.labelcolor'] = '#000000'
matplotlib.rcParams['xtick.color'] = '#000000'
matplotlib.rcParams['ytick.color'] = '#000000'

# %%
DF_GENES = '../../data/processed/cd-hit-results/sim80/Ebacter_strain_by_gene.pickle.gz'
ENRICHED_METADATA = '../../data/metadata/enriched_metadata.csv'
DF_EGGNOG = '../../data/processed/df_eggnog.csv'

DF_CORE_COMPLETE = '../../data/processed/CAR_genomes/df_core_complete.pickle'
DF_ACC_COMPLETE = '../../data/processed/CAR_genomes/df_acc_complete.pickle'
DF_RARE_COMPLETE = '../../data/processed/CAR_genomes/df_rare_complete.pickle'

L_BINARIZED = '../../data/processed/nmf-outputs/L_binarized.csv'
A_BINARIZED = '../../data/processed/nmf-outputs/A_binarized.csv'
L_MATRIX = '../../data/processed/nmf-outputs/L.csv'
A_MATRIX = '../../data/processed/nmf-outputs/A.csv'
BAKTA_ANNOTATIONS = '../../data/processed/bakta_gene_annotations.csv'

# %%
bakta_annotations = pd.read_csv(BAKTA_ANNOTATIONS, index_col=0)

# %%
gene_locs_acc = pd.read_csv('acc_gene_location.csv', index_col=0)
gene_locs = pd.read_csv('complete_gene_location.csv', index_col=0)

# %%
df_rare = pd.read_pickle(DF_RARE_COMPLETE)
df_acc = pd.read_pickle(DF_ACC_COMPLETE)
df_core = pd.read_pickle(DF_CORE_COMPLETE)

# %%
metadata = pd.read_csv(ENRICHED_METADATA, index_col=0, dtype='object')

display( metadata.shape, metadata.head())
# Out:
# (2575, 31)
#      genome_id                                  genome_name taxon_id  \
# 0  158836.1771             Enterobacter hormaechei FUJ80149   158836
# 1  158836.2297                 Enterobacter hormaechei EC50   158836
# 2    61645.609                Enterobacter asburiae C210030    61645
# 3   158836.809  Enterobacter hormaechei strain RHBSTW-00198   158836
# 4  158836.1952                Enterobacter hormaechei ECL66   158836
#
#   genome_status        strain       completion_date bioproject_accession  \
# 0           WGS      FUJ80149  2022-06-04T00:00:00Z           PRJDB13516
# 1           WGS          EC50  2023-03-20T00:00:00Z          PRJNA944415
# 2           WGS       C210030  1900-01-01T00:00:00Z          PRJNA837096
# 3      Complete  RHBSTW-00198  2020-07-27T00:00:00Z          PRJNA605147
# 4           WGS         ECL66  2022-07-03T00:00:00Z          PRJNA846540
#
#   biosample_accession assembly_accession                   genbank_accessions  \
# 0        SAMD00490860                NaN                         BRIC00000000
# 1        SAMN33748124                NaN                      JARJGB000000000
# 2        SAMN28189480    GCA_023753065.1                      JAMGNC000000000
# 3        SAMN15148534    GCA_013744415.1  CP056756,CP056757,CP056758,CP056759
# 4        SAMN28906575    GCA_024128555.1                      JAMYCZ000000000
#
#    ... refseq_cds                                   isolation_source  \
# 0  ...        NaN                                      not collected
# 1  ...       5227                                                NaN
# 2  ...       4727                                                NaN
# 3  ...       4561  Freshwater sample from downstream of wastewate...
# 4  ...       4784                                             sputum
#
#   collection_date isolation_country geographic_location     host_name  \
# 0      2019-12-22             Japan               Japan  Homo sapiens
# 1            2015             China      China: Sichuan  Homo sapiens
# 2            2021             China     China: Zhejiang  Homo sapiens
# 3            2017    United Kingdom      United Kingdom           NaN
# 4      2019-10-14             China    China: Chongqing  Homo sapiens
#
#                                             comments  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  These isolates represent a dataset assembled b...
# 4                                                NaN
#
#                                  additional_metadata complete_mash_cluster  \
# 0                                                NaN                   NaN
# 1                           collected_by:Lizhang Liu                   NaN
# 2                         sample_type:whole organism                   NaN
# 3  sample_type:culture;biomaterial_provider:Moder...                   3.0
# 4            collected_by:Department of Microbiology                   NaN
#
#   mlst
# 0   78
# 1  200
# 2  484
# 3   -1
# 4  177
#
# [5 rows x 31 columns]

# %%
# Load in (full) P matrix
df_genes = pd.read_pickle(DF_GENES)

# Filter metadata for Complete sequences only
metadata_complete = metadata[metadata.genome_status == 'Complete'] # filter for only Complete sequences

# Filter P matrix for Complete sequences only
df_genes_complete = df_genes[metadata_complete.genome_id].copy()
df_genes_complete.fillna(0, inplace=True) # replace N/A with 0
df_genes_complete = df_genes_complete.sparse.to_dense().astype('int8') # densify & typecast to int8 for space and compute reasons
inCompleteseqs = df_genes_complete.sum(axis=1) > 0 # filter for genes found in complete sequences
df_genes_complete = df_genes_complete[inCompleteseqs]

df_genes_complete.shape
# Out:
# (67539, 473)

# %%
# Load in eggNOG annotations
df_eggnog = pd.read_csv(DF_EGGNOG, index_col=0)
df_eggnog.fillna('-', inplace=True)

display(
    df_eggnog.shape,
    df_eggnog.head()
)
# Out:
# /tmp/ipykernel_2525767/221665879.py:2: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_eggnog = pd.read_csv(DF_EGGNOG, index_col=0)
# (128358, 21)
#                           allele         seed_ortholog evalue   score  \
# gene
# Ebacter_C27603  Ebacter_C27603A0      716541.ECL_01176    0.0   618.0
# Ebacter_C6462    Ebacter_C6462A0  1045856.EcWSU1_00942    0.0  1217.0
# Ebacter_C31898  Ebacter_C31898A0      716541.ECL_01178    0.0   553.0
# Ebacter_C44055  Ebacter_C44055A0      693444.D782_3430    0.0   306.0
# Ebacter_C14404  Ebacter_C14404A0      693444.D782_3429    0.0   768.0
#
#                                                        eggNOG_OGs  \
# gene
# Ebacter_C27603  COG0667@1|root,COG0667@2|Bacteria,1MV2Y@1224|P...
# Ebacter_C6462   COG1154@1|root,COG1154@2|Bacteria,1MUSJ@1224|P...
# Ebacter_C31898  COG0142@1|root,COG0142@2|Bacteria,1MWNG@1224|P...
# Ebacter_C44055  COG0363@1|root,COG0363@2|Bacteria,1R8UH@1224|P...
# Ebacter_C14404  COG1486@1|root,COG1486@2|Bacteria,1NI6G@1224|P...
#
#                max_annot_lvl COG_category  \
# gene
# Ebacter_C27603    2|Bacteria            C
# Ebacter_C6462     2|Bacteria            H
# Ebacter_C31898    2|Bacteria            H
# Ebacter_C44055    2|Bacteria            G
# Ebacter_C14404    2|Bacteria            G
#
#                                                       Description  \
# gene
# Ebacter_C27603                         Aldo/keto reductase family
# Ebacter_C6462   Catalyzes the acyloin condensation reaction be...
# Ebacter_C31898            Belongs to the FPP GGPP synthase family
# Ebacter_C44055                  glucosamine-6-phosphate deaminase
# Ebacter_C14404  Catalyzes the fromation of N-acetyl-D-glucosam...
#
#                Preferred_name  \
# gene
# Ebacter_C27603           yajO
# Ebacter_C6462             dxs
# Ebacter_C31898           ispA
# Ebacter_C44055           nagB
# Ebacter_C14404           celF
#
#                                                               GOs  ...  \
# gene                                                               ...
# Ebacter_C27603  GO:0003674,GO:0003824,GO:0005575,GO:0005622,GO...  ...
# Ebacter_C6462   GO:0000287,GO:0003674,GO:0003824,GO:0005488,GO...  ...
# Ebacter_C31898  GO:0003674,GO:0003824,GO:0004161,GO:0004337,GO...  ...
# Ebacter_C44055  GO:0003674,GO:0003824,GO:0005575,GO:0005622,GO...  ...
# Ebacter_C14404                                                  -  ...
#
#                                       KEGG_ko  \
# gene
# Ebacter_C27603                      ko:K05882
# Ebacter_C6462                       ko:K01662
# Ebacter_C31898  ko:K00795,ko:K02523,ko:K13789
# Ebacter_C44055  ko:K01057,ko:K02080,ko:K02564
# Ebacter_C14404            ko:K01222,ko:K01232
#
#                                                      KEGG_Pathway  \
# gene
# Ebacter_C27603                                                  -
# Ebacter_C6462   ko00730,ko00900,ko01100,ko01110,ko01130,map007...
# Ebacter_C31898  ko00900,ko01100,ko01110,ko01130,map00900,map01...
# Ebacter_C44055  ko00030,ko00052,ko00520,ko01100,ko01110,ko0112...
# Ebacter_C14404                  ko00010,ko00500,map00010,map00500
#
#                          KEGG_Module  \
# gene
# Ebacter_C27603                     -
# Ebacter_C6462                 M00096
# Ebacter_C31898         M00364,M00366
# Ebacter_C44055  M00004,M00006,M00008
# Ebacter_C14404                     -
#
#                                             KEGG_Reaction  \
# gene
# Ebacter_C27603                                          -
# Ebacter_C6462                                      R05636
# Ebacter_C31898                R01658,R02003,R02061,R09248
# Ebacter_C44055                       R00765,R02035,R08365
# Ebacter_C14404  R00837,R00838,R00839,R05133,R05134,R06113
#
#                             KEGG_rclass  \
# gene
# Ebacter_C27603                        -
# Ebacter_C6462                   RC00032
# Ebacter_C31898                  RC00279
# Ebacter_C44055          RC00163,RC00537
# Ebacter_C14404  RC00049,RC00171,RC00714
#
#                                                   BRITE KEGG_TC     CAZy  \
# gene
# Ebacter_C27603                          ko00000,ko01000       -        -
# Ebacter_C6462           ko00000,ko00001,ko00002,ko01000       -        -
# Ebacter_C31898  ko00000,ko00001,ko00002,ko01000,ko01006       -        -
# Ebacter_C44055          ko00000,ko00001,ko00002,ko01000       -        -
# Ebacter_C14404                  ko00000,ko00001,ko01000       -  GH4,GT4
#
#                                                     BiGG_Reaction  \
# gene
# Ebacter_C27603                                                  -
# Ebacter_C6462   iEcSMS35_1347.EcSMS35_0456,iIT341.HP0354,iJN74...
# Ebacter_C31898                  iPC815.YPO3176,iSFV_1184.SFV_0386
# Ebacter_C44055  iB21_1397.B21_02959,iECB_1328.ECB_03008,iECD_1...
# Ebacter_C14404                                                  -
#
#                                                       PFAMs
# gene
# Ebacter_C27603                                 Aldo_ket_red
# Ebacter_C6462   DXP_synthase_N,Transket_pyr,Transketolase_C
# Ebacter_C31898                              polyprenyl_synt
# Ebacter_C44055                              Glucosamine_iso
# Ebacter_C14404                 Glyco_hydro_4,Glyco_hydro_4C
#
# [5 rows x 21 columns]

# %%
# Load in A_binarized matrix
A_binarized = pd.read_csv(A_BINARIZED, index_col=0)
A_binarized
# Out:
#                             158836.809  550.1141  1686399.7  1296536.241  \
# hormaechei-steigerwaltii-1         0.0       1.0        0.0          0.0
# roggenkampii                       0.0       0.0        0.0          0.0
# hormaechei-hoffmannii-1            0.0       0.0        0.0          0.0
# unchar-1                           0.0       1.0        0.0          0.0
# ludwigii                           0.0       0.0        0.0          0.0
# hormaechei-xiangfangensis          0.0       0.0        0.0          1.0
# asburiae                           0.0       0.0        0.0          0.0
# kobei                              0.0       0.0        0.0          0.0
# cloacae                            0.0       0.0        0.0          0.0
# hormaechei-oharae                  1.0       0.0        0.0          0.0
# hormaechei-steigerwaltii-2         0.0       0.0        0.0          0.0
# hormaechei-steigerwaltii-3         0.0       0.0        0.0          0.0
# unchar-2                           0.0       0.0        0.0          0.0
# hormaechei-hormaechei              0.0       0.0        0.0          0.0
# unchar-3                           0.0       0.0        0.0          0.0
# bugandensis                        0.0       0.0        0.0          0.0
# cancerogenous                      0.0       0.0        0.0          0.0
# unchar-4                           0.0       0.0        0.0          0.0
# hormaechei-hoffmannii-2            0.0       0.0        0.0          0.0
#
#                             550.3830  1812935.464  1333851.3  208224.404  \
# hormaechei-steigerwaltii-1       0.0          0.0        0.0         0.0
# roggenkampii                     0.0          1.0        0.0         0.0
# hormaechei-hoffmannii-1          0.0          0.0        0.0         0.0
# unchar-1                         1.0          0.0        1.0         0.0
# ludwigii                         0.0          0.0        0.0         0.0
# hormaechei-xiangfangensis        1.0          0.0        0.0         0.0
# asburiae                         0.0          0.0        0.0         0.0
# kobei                            0.0          0.0        0.0         1.0
# cloacae                          0.0          0.0        0.0         0.0
# hormaechei-oharae                0.0          0.0        0.0         0.0
# hormaechei-steigerwaltii-2       0.0          0.0        0.0         0.0
# hormaechei-steigerwaltii-3       0.0          0.0        0.0         0.0
# unchar-2                         0.0          0.0        0.0         0.0
# hormaechei-hormaechei            0.0          0.0        0.0         0.0
# unchar-3                         0.0          0.0        0.0         0.0
# bugandensis                      0.0          0.0        0.0         0.0
# cancerogenous                    0.0          0.0        0.0         0.0
# unchar-4                         1.0          0.0        0.0         0.0
# hormaechei-hoffmannii-2          0.0          0.0        1.0         0.0
#
#                             158836.2021  158836.2356  ...  158836.801  \
# hormaechei-steigerwaltii-1          1.0          0.0  ...         0.0
# roggenkampii                        0.0          0.0  ...         0.0
# hormaechei-hoffmannii-1             0.0          0.0  ...         0.0
# unchar-1                            0.0          0.0  ...         0.0
# ludwigii                            0.0          0.0  ...         0.0
# hormaechei-xiangfangensis           0.0          0.0  ...         0.0
# asburiae                            0.0          0.0  ...         0.0
# kobei                               0.0          0.0  ...         0.0
# cloacae                             0.0          0.0  ...         0.0
# hormaechei-oharae                   0.0          0.0  ...         0.0
# hormaechei-steigerwaltii-2          0.0          0.0  ...         0.0
# hormaechei-steigerwaltii-3          0.0          0.0  ...         0.0
# unchar-2                            0.0          0.0  ...         0.0
# hormaechei-hormaechei               0.0          0.0  ...         0.0
# unchar-3                            0.0          0.0  ...         0.0
# bugandensis                         0.0          0.0  ...         0.0
# cancerogenous                       0.0          0.0  ...         0.0
# unchar-4                            0.0          0.0  ...         1.0
# hormaechei-hoffmannii-2             0.0          0.0  ...         1.0
#
#                             550.2813  158836.2201  550.2254  299766.198  \
# hormaechei-steigerwaltii-1       0.0          1.0       0.0         1.0
# roggenkampii                     1.0          0.0       0.0         0.0
# hormaechei-hoffmannii-1          0.0          0.0       0.0         0.0
# unchar-1                         0.0          0.0       0.0         0.0
# ludwigii                         0.0          0.0       0.0         0.0
# hormaechei-xiangfangensis        0.0          0.0       0.0         0.0
# asburiae                         0.0          0.0       0.0         0.0
# kobei                            0.0          0.0       0.0         0.0
# cloacae                          0.0          0.0       1.0         0.0
# hormaechei-oharae                0.0          0.0       0.0         0.0
# hormaechei-steigerwaltii-2       0.0          0.0       0.0         0.0
# hormaechei-steigerwaltii-3       0.0          0.0       0.0         0.0
# unchar-2                         0.0          0.0       0.0         0.0
# hormaechei-hormaechei            0.0          0.0       0.0         0.0
# unchar-3                         0.0          1.0       0.0         0.0
# bugandensis                      0.0          0.0       0.0         0.0
# cancerogenous                    0.0          0.0       0.0         0.0
# unchar-4                         0.0          0.0       0.0         0.0
# hormaechei-hoffmannii-2          0.0          0.0       0.0         0.0
#
#                             1045856.3  299766.187  158836.1100  299766.116  \
# hormaechei-steigerwaltii-1        0.0         1.0          0.0         0.0
# roggenkampii                      0.0         0.0          0.0         0.0
# hormaechei-hoffmannii-1           0.0         0.0          1.0         0.0
# unchar-1                          0.0         0.0          1.0         1.0
# ludwigii                          1.0         0.0          0.0         0.0
# hormaechei-xiangfangensis         0.0         0.0          0.0         0.0
# asburiae                          0.0         0.0          0.0         0.0
# kobei                             0.0         0.0          0.0         0.0
# cloacae                           0.0         0.0          0.0         0.0
# hormaechei-oharae                 0.0         0.0          0.0         0.0
# hormaechei-steigerwaltii-2        0.0         0.0          0.0         0.0
# hormaechei-steigerwaltii-3        0.0         0.0          0.0         0.0
# unchar-2                          0.0         1.0          0.0         0.0
# hormaechei-hormaechei             0.0         0.0          0.0         0.0
# unchar-3                          0.0         0.0          0.0         0.0
# bugandensis                       0.0         0.0          0.0         0.0
# cancerogenous                     0.0         0.0          0.0         0.0
# unchar-4                          0.0         0.0          0.0         0.0
# hormaechei-hoffmannii-2           0.0         0.0          0.0         0.0
#
#                             158836.2022
# hormaechei-steigerwaltii-1          1.0
# roggenkampii                        0.0
# hormaechei-hoffmannii-1             0.0
# unchar-1                            1.0
# ludwigii                            0.0
# hormaechei-xiangfangensis           0.0
# asburiae                            0.0
# kobei                               0.0
# cloacae                             0.0
# hormaechei-oharae                   0.0
# hormaechei-steigerwaltii-2          0.0
# hormaechei-steigerwaltii-3          0.0
# unchar-2                            0.0
# hormaechei-hormaechei               0.0
# unchar-3                            0.0
# bugandensis                         0.0
# cancerogenous                       0.0
# unchar-4                            0.0
# hormaechei-hoffmannii-2             0.0
#
# [19 rows x 473 columns]

# %%
# Load in L_binarized matrix
L_binarized = pd.read_csv(L_BINARIZED, index_col=0)
L_binarized
# Out:
#                  hormaechei-steigerwaltii-1  roggenkampii  \
# Ebacter_C15853                          0.0           1.0
# Ebacter_C51247                          0.0           0.0
# Ebacter_C100996                         0.0           0.0
# Ebacter_C20249                          0.0           1.0
# Ebacter_C95262                          0.0           0.0
# ...                                     ...           ...
# Ebacter_C76682                          0.0           0.0
# Ebacter_C440                            0.0           0.0
# Ebacter_C48006                          1.0           0.0
# Ebacter_C8929                           1.0           1.0
# Ebacter_C9313                           0.0           1.0
#
#                  hormaechei-hoffmannii-1  unchar-1  ludwigii  \
# Ebacter_C15853                       0.0       0.0       0.0
# Ebacter_C51247                       0.0       0.0       0.0
# Ebacter_C100996                      1.0       0.0       0.0
# Ebacter_C20249                       0.0       0.0       0.0
# Ebacter_C95262                       0.0       0.0       0.0
# ...                                  ...       ...       ...
# Ebacter_C76682                       0.0       0.0       0.0
# Ebacter_C440                         0.0       0.0       1.0
# Ebacter_C48006                       1.0       0.0       0.0
# Ebacter_C8929                        1.0       0.0       0.0
# Ebacter_C9313                        0.0       0.0       1.0
#
#                  hormaechei-xiangfangensis  asburiae  kobei  cloacae  \
# Ebacter_C15853                         0.0       0.0    0.0      0.0
# Ebacter_C51247                         0.0       0.0    0.0      0.0
# Ebacter_C100996                        0.0       0.0    0.0      0.0
# Ebacter_C20249                         0.0       0.0    0.0      0.0
# Ebacter_C95262                         0.0       0.0    1.0      1.0
# ...                                    ...       ...    ...      ...
# Ebacter_C76682                         0.0       0.0    0.0      0.0
# Ebacter_C440                           0.0       0.0    0.0      0.0
# Ebacter_C48006                         1.0       0.0    0.0      0.0
# Ebacter_C8929                          1.0       1.0    1.0      1.0
# Ebacter_C9313                          0.0       1.0    1.0      0.0
#
#                  hormaechei-oharae  hormaechei-steigerwaltii-2  \
# Ebacter_C15853                 0.0                         0.0
# Ebacter_C51247                 0.0                         0.0
# Ebacter_C100996                0.0                         0.0
# Ebacter_C20249                 0.0                         0.0
# Ebacter_C95262                 0.0                         0.0
# ...                            ...                         ...
# Ebacter_C76682                 0.0                         0.0
# Ebacter_C440                   0.0                         0.0
# Ebacter_C48006                 1.0                         1.0
# Ebacter_C8929                  1.0                         1.0
# Ebacter_C9313                  0.0                         0.0
#
#                  hormaechei-steigerwaltii-3  unchar-2  hormaechei-hormaechei  \
# Ebacter_C15853                          0.0       0.0                    0.0
# Ebacter_C51247                          0.0       1.0                    0.0
# Ebacter_C100996                         0.0       0.0                    0.0
# Ebacter_C20249                          0.0       0.0                    0.0
# Ebacter_C95262                          0.0       0.0                    0.0
# ...                                     ...       ...                    ...
# Ebacter_C76682                          0.0       0.0                    0.0
# Ebacter_C440                            0.0       0.0                    0.0
# Ebacter_C48006                          1.0       0.0                    1.0
# Ebacter_C8929                           0.0       0.0                    0.0
# Ebacter_C9313                           0.0       0.0                    0.0
#
#                  unchar-3  bugandensis  cancerogenous  unchar-4  \
# Ebacter_C15853        0.0          0.0            0.0       0.0
# Ebacter_C51247        0.0          0.0            0.0       0.0
# Ebacter_C100996       0.0          0.0            0.0       0.0
# Ebacter_C20249        0.0          0.0            0.0       0.0
# Ebacter_C95262        0.0          0.0            0.0       0.0
# ...                   ...          ...            ...       ...
# Ebacter_C76682        0.0          0.0            0.0       0.0
# Ebacter_C440          0.0          0.0            0.0       0.0
# Ebacter_C48006        0.0          0.0            1.0       0.0
# Ebacter_C8929         0.0          0.0            0.0       0.0
# Ebacter_C9313         0.0          1.0            0.0       0.0
#
#                  hormaechei-hoffmannii-2
# Ebacter_C15853                       0.0
# Ebacter_C51247                       0.0
# Ebacter_C100996                      0.0
# Ebacter_C20249                       0.0
# Ebacter_C95262                       0.0
# ...                                  ...
# Ebacter_C76682                       0.0
# Ebacter_C440                         0.0
# Ebacter_C48006                       1.0
# Ebacter_C8929                        1.0
# Ebacter_C9313                        0.0
#
# [4889 rows x 19 columns]

# %%
phylon_order = ['hormaechei-xiangfangensis',
 'hormaechei-oharae',
 'hormaechei-steigerwaltii-2',
 'hormaechei-steigerwaltii-1',
 'hormaechei-steigerwaltii-3',
 'hormaechei-hormaechei',
 'hormaechei-hoffmannii-1',
 'hormaechei-hoffmannii-2',
 'unchar-1',
 'unchar-2',
 'unchar-3',
 'unchar-4',
 'roggenkampii',
 'asburiae',
 'kobei',
 'bugandensis',
 'cancerogenous',
 'ludwigii',
 'cloacae']

characterized_order = ['hormaechei-xiangfangensis',
 'hormaechei-oharae',
 'hormaechei-steigerwaltii-2',
 'hormaechei-steigerwaltii-1',
 'hormaechei-steigerwaltii-3',
 'hormaechei-hormaechei',
 'hormaechei-hoffmannii-1',
 'hormaechei-hoffmannii-2',
 'roggenkampii',
 'asburiae',
 'kobei',
 'bugandensis',
 'cancerogenous',
 'ludwigii',
 'cloacae']

# %% [markdown]
# # Analysis of motility genes of Steigerwaltii phylons

# %%
def get_strains(phylon, A_binarized = A_binarized):
    phylon_membership = A_binarized.loc[phylon]
    return (phylon_membership[phylon_membership == 1]).index

def get_genes(phylon, L_binarized = L_binarized):
    return [x for x in L_binarized.index if L_binarized.loc[x, phylon] > 0]

def get_shared_genes(phylons, L_binarized = L_binarized):
    if type(phylons) == type(""):
        phylons = [phylons]
    return [x for x in L_binarized.index if L_binarized.loc[x,phylons].sum() == len(phylons) and L_binarized.drop(phylons, axis = 1).loc[x].sum() == 0]

# %%
phylons = ['hormaechei-steigerwaltii-3', 'hormaechei-steigerwaltii-1']

# %%
shared_genes = get_shared_genes(phylons)

isMotility1 = df_eggnog.loc[shared_genes].COG_category.str.contains('N')
isMotility2 = df_eggnog.loc[shared_genes].Description.str.contains('pilus')
isMotility3 = df_eggnog.loc[shared_genes].Description.str.contains('pili')

steigerwaltii13_motility = df_eggnog.loc[shared_genes][isMotility1 | isMotility2 | isMotility3]
steigerwaltii13_motility.shape[0]
# Out:
# 43

# %%
steigerwaltii13_motility
# Out:
#                             allele         seed_ortholog    evalue   score  \
# gene
# Ebacter_C81012    Ebacter_C81012A0     95619.PM1_0219485  0.000001    53.1
# Ebacter_C17706    Ebacter_C17706A0      716541.ECL_03274       0.0   524.0
# Ebacter_C62234    Ebacter_C62234A0      716541.ECL_03296       0.0   223.0
# Ebacter_C74657    Ebacter_C74657A0      716541.ECL_03280       0.0   211.0
# Ebacter_C26995    Ebacter_C26995A0      716541.ECL_03301       0.0   571.0
# Ebacter_C77936    Ebacter_C77936A0      716541.ECL_03311       0.0   166.0
# Ebacter_C45587    Ebacter_C45587A0      716541.ECL_03300       0.0   253.0
# Ebacter_C20772   Ebacter_C20772A47      716541.ECL_03270  1.4e-231   642.0
# Ebacter_C45044    Ebacter_C45044A0     701347.Entcl_0630       0.0   322.0
# Ebacter_C87336    Ebacter_C87336A0      716541.ECL_03264       0.0   205.0
# Ebacter_C91316    Ebacter_C91316A0      716541.ECL_03304       0.0   156.0
# Ebacter_C63709    Ebacter_C63709A0  198628.Dda3937_02209       0.0   263.0
# Ebacter_C26698    Ebacter_C26698A0      716541.ECL_03295       0.0   588.0
# Ebacter_C73894    Ebacter_C73894A0      716541.ECL_03298       0.0   207.0
# Ebacter_C20134    Ebacter_C20134A0      716541.ECL_03309       0.0   591.0
# Ebacter_C8728      Ebacter_C8728A0      716541.ECL_03268       0.0   675.0
# Ebacter_C31523    Ebacter_C31523A0      716541.ECL_03261       0.0   473.0
# Ebacter_C32116    Ebacter_C32116A0      716541.ECL_03262       0.0   508.0
# Ebacter_C42833    Ebacter_C42833A0      665029.EAMY_2664       0.0   390.0
# Ebacter_C39565    Ebacter_C39565A0      665029.EAMY_2682       0.0   325.0
# Ebacter_C23423   Ebacter_C23423A32      716541.ECL_03297       0.0   246.0
# Ebacter_C46083    Ebacter_C46083A0      665029.EAMY_2666       0.0   218.0
# Ebacter_C79052    Ebacter_C79052A0      716541.ECL_03277       0.0   226.0
# Ebacter_C10828    Ebacter_C10828A0      716541.ECL_03284       0.0   538.0
# Ebacter_C46082    Ebacter_C46082A0      716541.ECL_03278       0.0   281.0
# Ebacter_C42326    Ebacter_C42326A0      665029.EAMY_2684       0.0   347.0
# Ebacter_C13196    Ebacter_C13196A0      716541.ECL_03299       0.0   780.0
# Ebacter_C8278     Ebacter_C8278A29      665029.EAMY_2694       0.0   774.0
# Ebacter_C79854    Ebacter_C79854A0      716541.ECL_03276       0.0   229.0
# Ebacter_C5478      Ebacter_C5478A0      716541.ECL_03260       0.0   931.0
# Ebacter_C32304    Ebacter_C32304A0      716541.ECL_03267       0.0   381.0
# Ebacter_C82704    Ebacter_C82704A0      716541.ECL_03294       0.0   217.0
# Ebacter_C66693    Ebacter_C66693A0      716541.ECL_03259       0.0   248.0
# Ebacter_C83806    Ebacter_C83806A3     911008.GLAD_00768       0.0   202.0
# Ebacter_C39362    Ebacter_C39362A0      716541.ECL_03272       0.0   434.0
# Ebacter_C8877      Ebacter_C8877A0      716541.ECL_03266       0.0   535.0
# Ebacter_C79469    Ebacter_C79469A0      716541.ECL_03282       0.0   231.0
# Ebacter_C100471  Ebacter_C100471A0      665029.EAMY_2683       0.0   133.0
# Ebacter_C30092    Ebacter_C30092A0      716541.ECL_03269       0.0   454.0
# Ebacter_C4751     Ebacter_C4751A32      716541.ECL_03310       0.0  1287.0
# Ebacter_C23562    Ebacter_C23562A0      716541.ECL_03306       0.0   516.0
# Ebacter_C51220    Ebacter_C51220A0      716541.ECL_03308       0.0   311.0
# Ebacter_C10671    Ebacter_C10671A0      716541.ECL_03283       0.0   497.0
#
#                                                         eggNOG_OGs  \
# gene
# Ebacter_C81012   COG3190@1|root,COG3190@2|Bacteria,1N79Z@1224|P...
# Ebacter_C17706   COG1749@1|root,COG1749@2|Bacteria,1MU5J@1224|P...
# Ebacter_C62234   COG1580@1|root,COG1580@2|Bacteria,1PX2D@1224|P...
# Ebacter_C74657   COG3418@1|root,COG3418@2|Bacteria,1QR4K@1224|P...
# Ebacter_C26995   COG1536@1|root,COG1536@2|Bacteria,1MV9X@1224|P...
# Ebacter_C77936   2DQI4@1|root,33700@2|Bacteria,1NAB2@1224|Prote...
# Ebacter_C45587   COG1317@1|root,COG1317@2|Bacteria,1NMQE@1224|P...
# Ebacter_C20772   COG1706@1|root,COG1706@2|Bacteria,1MVKW@1224|P...
# Ebacter_C45044   COG3121@1|root,COG3121@2|Bacteria,1R3T9@1224|P...
# Ebacter_C87336   2AX91@1|root,31P80@2|Bacteria,1RJCE@1224|Prote...
# Ebacter_C91316   COG1677@1|root,COG1677@2|Bacteria,1Q81W@1224|P...
# Ebacter_C63709   COG2063@1|root,COG2063@2|Bacteria,1RDEY@1224|P...
# Ebacter_C26698   COG1868@1|root,COG1868@2|Bacteria,1MX01@1224|P...
# Ebacter_C73894   COG2882@1|root,COG2882@2|Bacteria,1PUI6@1224|P...
# Ebacter_C20134   COG1377@1|root,COG1377@2|Bacteria,1MUWI@1224|P...
# Ebacter_C8728    COG1256@1|root,COG1256@2|Bacteria,1MV2M@1224|P...
# Ebacter_C31523   COG1360@1|root,COG1360@2|Bacteria,1MW1Y@1224|P...
# Ebacter_C32116   COG1291@1|root,COG1291@2|Bacteria,1MXK3@1224|P...
# Ebacter_C42833   COG4787@1|root,COG4787@2|Bacteria,1NZWQ@1224|P...
# Ebacter_C39565   COG1684@1|root,COG1684@2|Bacteria,1NT4F@1224|P...
# Ebacter_C23423   COG3144@1|root,COG3144@2|Bacteria,1N7XT@1224|P...
# Ebacter_C46083   COG1843@1|root,COG1843@2|Bacteria,1PQS5@1224|P...
# Ebacter_C79052   COG1815@1|root,COG1815@2|Bacteria,1MZ8P@1224|P...
# Ebacter_C10828   COG1344@1|root,COG1344@2|Bacteria,1MV1N@1224|P...
# Ebacter_C46082   COG1261@1|root,COG1261@2|Bacteria,1PCYH@1224|P...
# Ebacter_C42326   COG1338@1|root,COG1338@2|Bacteria,1MVBU@1224|P...
# Ebacter_C13196   COG1157@1|root,COG1157@2|Bacteria,1MUH6@1224|P...
# Ebacter_C8278    COG1766@1|root,COG1766@2|Bacteria,1MUQR@1224|P...
# Ebacter_C79854   COG1558@1|root,COG1558@2|Bacteria,1RHI3@1224|P...
# Ebacter_C5478    COG0643@1|root,COG2198@1|root,COG0643@2|Bacter...
# Ebacter_C32304   COG1344@1|root,COG1344@2|Bacteria,1PJUJ@1224|P...
# Ebacter_C82704   COG1886@1|root,COG1886@2|Bacteria,1RGWT@1224|P...
# Ebacter_C66693   COG0835@1|root,COG0835@2|Bacteria,1RD1W@1224|P...
# Ebacter_C83806   COG3190@1|root,COG3190@2|Bacteria,1N79Z@1224|P...
# Ebacter_C39362   COG4786@1|root,COG4786@2|Bacteria,1MVMA@1224|P...
# Ebacter_C8877    COG0840@1|root,COG0840@2|Bacteria,1MU9B@1224|P...
# Ebacter_C79469   COG1516@1|root,COG1516@2|Bacteria,1MZ3G@1224|P...
# Ebacter_C100471  COG1987@1|root,COG1987@2|Bacteria,1NY9B@1224|P...
# Ebacter_C30092   COG1705@1|root,COG3951@1|root,COG1705@2|Bacter...
# Ebacter_C4751    COG1298@1|root,COG1298@2|Bacteria,1MUF3@1224|P...
# Ebacter_C23562   COG2201@1|root,COG2201@2|Bacteria,1MWCN@1224|P...
# Ebacter_C51220   COG3143@1|root,COG3143@2|Bacteria,1NIV6@1224|P...
# Ebacter_C10671   COG1345@1|root,COG1345@2|Bacteria,1MUVP@1224|P...
#
#                 max_annot_lvl COG_category  \
# gene
# Ebacter_C81012     2|Bacteria            N
# Ebacter_C17706     2|Bacteria            N
# Ebacter_C62234     2|Bacteria            N
# Ebacter_C74657     2|Bacteria            N
# Ebacter_C26995     2|Bacteria            N
# Ebacter_C77936     2|Bacteria            N
# Ebacter_C45587     2|Bacteria            N
# Ebacter_C20772     2|Bacteria            N
# Ebacter_C45044     2|Bacteria           NU
# Ebacter_C87336     2|Bacteria            N
# Ebacter_C91316     2|Bacteria            N
# Ebacter_C63709     2|Bacteria            N
# Ebacter_C26698     2|Bacteria            N
# Ebacter_C73894     2|Bacteria            N
# Ebacter_C20134     2|Bacteria            N
# Ebacter_C8728      2|Bacteria            N
# Ebacter_C31523     2|Bacteria            N
# Ebacter_C32116     2|Bacteria            N
# Ebacter_C42833     2|Bacteria            N
# Ebacter_C39565     2|Bacteria            N
# Ebacter_C23423     2|Bacteria            N
# Ebacter_C46083     2|Bacteria            N
# Ebacter_C79052     2|Bacteria            N
# Ebacter_C10828     2|Bacteria            N
# Ebacter_C46082     2|Bacteria            N
# Ebacter_C42326     2|Bacteria            N
# Ebacter_C13196     2|Bacteria           NU
# Ebacter_C8278      2|Bacteria            N
# Ebacter_C79854     2|Bacteria            N
# Ebacter_C5478      2|Bacteria           NT
# Ebacter_C32304     2|Bacteria            N
# Ebacter_C82704     2|Bacteria            N
# Ebacter_C66693     2|Bacteria           NT
# Ebacter_C83806     2|Bacteria            N
# Ebacter_C39362     2|Bacteria            N
# Ebacter_C8877      2|Bacteria           NT
# Ebacter_C79469     2|Bacteria            N
# Ebacter_C100471    2|Bacteria            N
# Ebacter_C30092     2|Bacteria            N
# Ebacter_C4751      2|Bacteria            N
# Ebacter_C23562     2|Bacteria           NT
# Ebacter_C51220     2|Bacteria           NT
# Ebacter_C10671     2|Bacteria            N
#
#                                                        Description  \
# gene
# Ebacter_C81012                                           flagellar
# Ebacter_C17706                   Flagellar basal body protein FlaE
# Ebacter_C62234   Controls the rotational direction of flagella ...
# Ebacter_C74657                                        FlgN protein
# Ebacter_C26995   FliG is one of three proteins (FliG, FliN, Fli...
# Ebacter_C77936                              Flagellar protein FlhE
# Ebacter_C45587                     Flagellar assembly protein FliH
# Ebacter_C20772   Assembles around the rod to form the L-ring an...
# Ebacter_C45044     Pili assembly chaperone PapD, C-terminal domain
# Ebacter_C87336   Functions in complex with FlhC as a master tra...
# Ebacter_C91316      Flagellar hook-basal body complex protein FliE
# Ebacter_C63709   Assembles around the rod to form the L-ring an...
# Ebacter_C26698   FliM is one of three proteins (FliG, FliN, Fli...
# Ebacter_C73894   Flagellar protein that affects chemotactic events
# Ebacter_C20134   Required for formation of the rod structure in...
# Ebacter_C8728    Flagellar basal body rod FlgEFG protein C-term...
# Ebacter_C31523   Membrane MotB of proton-channel complex MotA/MotB
# Ebacter_C32116   With MotB forms the ion channels that couple f...
# Ebacter_C42833               Flagellar basal-body rod protein FlgF
# Ebacter_C39565                 Flagellar biosynthetic protein FliR
# Ebacter_C23423          Flagellar hook-length control protein FliK
# Ebacter_C46083            Basal-body rod modification protein FlgD
# Ebacter_C79052   Structural component of flagellum, the bacteri...
# Ebacter_C10828   Flagellin is the subunit protein which polymer...
# Ebacter_C46082   Involved in the assembly process of the P-ring...
# Ebacter_C42326                 Flagellar biosynthetic protein FliP
# Ebacter_C13196   ATP synthase alpha/beta family, nucleotide-bin...
# Ebacter_C8278    The M ring may be actively involved in energy ...
# Ebacter_C79854   Flagellar basal body rod FlgEFG protein C-term...
# Ebacter_C5478            CheA signal transduction histidine kinase
# Ebacter_C32304       Bacterial flagellin N-terminal helical region
# Ebacter_C82704   FliN is one of three proteins (FliG, FliN, Fli...
# Ebacter_C66693             Two component signalling adaptor domain
# Ebacter_C83806                                           flagellar
# Ebacter_C39362   Belongs to the flagella basal body rod protein...
# Ebacter_C8877    Methyl-accepting chemotaxis-like domains (chem...
# Ebacter_C79469                              Flagellar protein FliS
# Ebacter_C100471                Flagellar biosynthetic protein FliQ
# Ebacter_C30092                                 Rod binding protein
# Ebacter_C4751    Required for formation of the rod structure of...
# Ebacter_C23562   catalyzes the demethylation of specific methyl...
# Ebacter_C51220   Plays an important role in bacterial chemotaxi...
# Ebacter_C10671   Required for morphogenesis and for the elongat...
#
#                 Preferred_name  \
# gene
# Ebacter_C81012            fliO
# Ebacter_C17706            flgE
# Ebacter_C62234            fliL
# Ebacter_C74657            flgN
# Ebacter_C26995            fliG
# Ebacter_C77936               -
# Ebacter_C45587            fliH
# Ebacter_C20772            flgI
# Ebacter_C45044            elfD
# Ebacter_C87336            flhD
# Ebacter_C91316            fliE
# Ebacter_C63709            flgH
# Ebacter_C26698            fliM
# Ebacter_C73894            fliJ
# Ebacter_C20134            flhB
# Ebacter_C8728             flgK
# Ebacter_C31523            motB
# Ebacter_C32116            motA
# Ebacter_C42833            flgF
# Ebacter_C39565            fliR
# Ebacter_C23423            fliK
# Ebacter_C46083            flgD
# Ebacter_C79052            flgB
# Ebacter_C10828            fliC
# Ebacter_C46082            flgA
# Ebacter_C42326            fliP
# Ebacter_C13196            fliI
# Ebacter_C8278             fliF
# Ebacter_C79854            flgC
# Ebacter_C5478             cheA
# Ebacter_C32304            flgL
# Ebacter_C82704            fliN
# Ebacter_C66693            cheW
# Ebacter_C83806            fliO
# Ebacter_C39362            flgG
# Ebacter_C8877              tar
# Ebacter_C79469            fliS
# Ebacter_C100471           fliQ
# Ebacter_C30092            flgJ
# Ebacter_C4751             flhA
# Ebacter_C23562            cheB
# Ebacter_C51220            cheZ
# Ebacter_C10671            fliD
#
#                                                                GOs  ...  \
# gene                                                                ...
# Ebacter_C81012                                                   -  ...
# Ebacter_C17706                                                   -  ...
# Ebacter_C62234                                                   -  ...
# Ebacter_C74657                                                   -  ...
# Ebacter_C26995   GO:0001539,GO:0003674,GO:0005488,GO:0005515,GO...  ...
# Ebacter_C77936                                                   -  ...
# Ebacter_C45587                                                   -  ...
# Ebacter_C20772                                                   -  ...
# Ebacter_C45044   GO:0008150,GO:0009987,GO:0016043,GO:0030030,GO...  ...
# Ebacter_C87336                                                   -  ...
# Ebacter_C91316                                                   -  ...
# Ebacter_C63709   GO:0006950,GO:0006970,GO:0008150,GO:0009628,GO...  ...
# Ebacter_C26698                                                   -  ...
# Ebacter_C73894                                                   -  ...
# Ebacter_C20134                                                   -  ...
# Ebacter_C8728                                                    -  ...
# Ebacter_C31523                                                   -  ...
# Ebacter_C32116   GO:0006935,GO:0008150,GO:0009605,GO:0040011,GO...  ...
# Ebacter_C42833                                                   -  ...
# Ebacter_C39565                                                   -  ...
# Ebacter_C23423                                                   -  ...
# Ebacter_C46083                                                   -  ...
# Ebacter_C79052                                                   -  ...
# Ebacter_C10828   GO:0005575,GO:0005576,GO:0005623,GO:0009288,GO...  ...
# Ebacter_C46082                                                   -  ...
# Ebacter_C42326                                                   -  ...
# Ebacter_C13196                                                   -  ...
# Ebacter_C8278                                                    -  ...
# Ebacter_C79854                                                   -  ...
# Ebacter_C5478          GO:0003674,GO:0005488,GO:0005515,GO:0019904  ...
# Ebacter_C32304                                                   -  ...
# Ebacter_C82704                                                   -  ...
# Ebacter_C66693                                                   -  ...
# Ebacter_C83806                                                   -  ...
# Ebacter_C39362                                                   -  ...
# Ebacter_C8877                                                    -  ...
# Ebacter_C79469                               GO:0003674,GO:0005198  ...
# Ebacter_C100471                                                  -  ...
# Ebacter_C30092                               GO:0003674,GO:0005198  ...
# Ebacter_C4751                                                    -  ...
# Ebacter_C23562   GO:0006935,GO:0008150,GO:0009605,GO:0040011,GO...  ...
# Ebacter_C51220                                                   -  ...
# Ebacter_C10671   GO:0001539,GO:0005575,GO:0005576,GO:0005623,GO...  ...
#
#                                                            KEGG_ko  \
# gene
# Ebacter_C81012                                           ko:K02418
# Ebacter_C17706                                           ko:K02390
# Ebacter_C62234                                           ko:K02415
# Ebacter_C74657                                           ko:K02399
# Ebacter_C26995                                           ko:K02410
# Ebacter_C77936                                           ko:K03516
# Ebacter_C45587                                           ko:K02411
# Ebacter_C20772                                           ko:K02394
# Ebacter_C45044                                           ko:K07346
# Ebacter_C87336                                           ko:K02403
# Ebacter_C91316                                           ko:K02408
# Ebacter_C63709                                           ko:K02393
# Ebacter_C26698                                           ko:K02416
# Ebacter_C73894                                           ko:K02413
# Ebacter_C20134   ko:K02401,ko:K02556,ko:K03229,ko:K04061,ko:K13820
# Ebacter_C8728                                            ko:K02396
# Ebacter_C31523                                           ko:K02557
# Ebacter_C32116                                           ko:K02556
# Ebacter_C42833                                           ko:K02391
# Ebacter_C39565                                           ko:K02421
# Ebacter_C23423                                           ko:K02414
# Ebacter_C46083                                           ko:K02389
# Ebacter_C79052                                           ko:K02387
# Ebacter_C10828                                           ko:K02406
# Ebacter_C46082                                 ko:K02279,ko:K02386
# Ebacter_C42326                                 ko:K02419,ko:K03226
# Ebacter_C13196                                           ko:K02412
# Ebacter_C8278                                            ko:K02409
# Ebacter_C79854                                           ko:K02388
# Ebacter_C5478                        ko:K02487,ko:K03407,ko:K06596
# Ebacter_C32304                                           ko:K02397
# Ebacter_C82704                                           ko:K02417
# Ebacter_C66693                                 ko:K03408,ko:K03415
# Ebacter_C83806                                           ko:K02418
# Ebacter_C39362                                           ko:K02392
# Ebacter_C8877    ko:K03406,ko:K05874,ko:K05875,ko:K05876,ko:K05877
# Ebacter_C79469                                           ko:K02422
# Ebacter_C100471                                          ko:K02420
# Ebacter_C30092                                 ko:K01448,ko:K02395
# Ebacter_C4751                                            ko:K02400
# Ebacter_C23562                                           ko:K03412
# Ebacter_C51220                                           ko:K03414
# Ebacter_C10671                                           ko:K02407
#
#                                                       KEGG_Pathway  \
# gene
# Ebacter_C81012                                    ko02040,map02040
# Ebacter_C17706                                    ko02040,map02040
# Ebacter_C62234                                                   -
# Ebacter_C74657                                    ko02040,map02040
# Ebacter_C26995                   ko02030,ko02040,map02030,map02040
# Ebacter_C77936                                                   -
# Ebacter_C45587                                    ko02040,map02040
# Ebacter_C20772                                    ko02040,map02040
# Ebacter_C45044                                                   -
# Ebacter_C87336   ko02020,ko02024,ko02026,ko02040,map02020,map02...
# Ebacter_C91316                                    ko02040,map02040
# Ebacter_C63709                                    ko02040,map02040
# Ebacter_C26698                   ko02030,ko02040,map02030,map02040
# Ebacter_C73894                                    ko02040,map02040
# Ebacter_C20134   ko02020,ko02030,ko02040,ko03070,map02020,map02...
# Ebacter_C8728                                     ko02040,map02040
# Ebacter_C31523                   ko02030,ko02040,map02030,map02040
# Ebacter_C32116   ko02020,ko02030,ko02040,map02020,map02030,map0...
# Ebacter_C42833                                    ko02040,map02040
# Ebacter_C39565                                    ko02040,map02040
# Ebacter_C23423                                    ko02040,map02040
# Ebacter_C46083                                    ko02040,map02040
# Ebacter_C79052                                    ko02040,map02040
# Ebacter_C10828   ko02020,ko02040,ko04621,ko04626,ko05132,ko0513...
# Ebacter_C46082                                    ko02040,map02040
# Ebacter_C42326                   ko02040,ko03070,map02040,map03070
# Ebacter_C13196                                    ko02040,map02040
# Ebacter_C8278                                     ko02040,map02040
# Ebacter_C79854                                    ko02040,map02040
# Ebacter_C5478    ko02020,ko02025,ko02030,map02020,map02025,map0...
# Ebacter_C32304                                    ko02040,map02040
# Ebacter_C82704                   ko02030,ko02040,map02030,map02040
# Ebacter_C66693                   ko02020,ko02030,map02020,map02030
# Ebacter_C83806                                    ko02040,map02040
# Ebacter_C39362                                    ko02040,map02040
# Ebacter_C8877                    ko02020,ko02030,map02020,map02030
# Ebacter_C79469                                    ko02040,map02040
# Ebacter_C100471                                   ko02040,map02040
# Ebacter_C30092                                    ko01503,map01503
# Ebacter_C4751                                     ko02040,map02040
# Ebacter_C23562                   ko02020,ko02030,map02020,map02030
# Ebacter_C51220                                    ko02030,map02030
# Ebacter_C10671                                    ko02040,map02040
#
#                           KEGG_Module KEGG_Reaction      KEGG_rclass  \
# gene
# Ebacter_C81012                      -             -                -
# Ebacter_C17706                      -             -                -
# Ebacter_C62234                      -             -                -
# Ebacter_C74657                      -             -                -
# Ebacter_C26995                      -             -                -
# Ebacter_C77936                      -             -                -
# Ebacter_C45587                      -             -                -
# Ebacter_C20772                      -             -                -
# Ebacter_C45044                      -             -                -
# Ebacter_C87336                      -             -                -
# Ebacter_C91316                      -             -                -
# Ebacter_C63709                      -             -                -
# Ebacter_C26698                      -             -                -
# Ebacter_C73894                      -             -                -
# Ebacter_C20134   M00332,M00542,M00660             -                -
# Ebacter_C8728                       -             -                -
# Ebacter_C31523                      -             -                -
# Ebacter_C32116                      -             -                -
# Ebacter_C42833                      -             -                -
# Ebacter_C39565                      -             -                -
# Ebacter_C23423                      -             -                -
# Ebacter_C46083                      -             -                -
# Ebacter_C79052                      -             -                -
# Ebacter_C10828                      -             -                -
# Ebacter_C46082                      -             -                -
# Ebacter_C42326   M00332,M00542,M00660             -                -
# Ebacter_C13196                      -             -                -
# Ebacter_C8278                       -             -                -
# Ebacter_C79854                      -             -                -
# Ebacter_C5478           M00506,M00507             -                -
# Ebacter_C32304                      -             -                -
# Ebacter_C82704                      -             -                -
# Ebacter_C66693                 M00506             -                -
# Ebacter_C83806                      -             -                -
# Ebacter_C39362                      -             -                -
# Ebacter_C8877                       -             -                -
# Ebacter_C79469                      -             -                -
# Ebacter_C100471                     -             -                -
# Ebacter_C30092                 M00727        R04112  RC00064,RC00141
# Ebacter_C4751                       -             -                -
# Ebacter_C23562                 M00506             -                -
# Ebacter_C51220                      -             -                -
# Ebacter_C10671                      -             -                -
#
#                                                              BRITE  \
# gene
# Ebacter_C81012                     ko00000,ko00001,ko02035,ko02044
# Ebacter_C17706                             ko00000,ko00001,ko02035
# Ebacter_C62234                                     ko00000,ko02035
# Ebacter_C74657                             ko00000,ko00001,ko02035
# Ebacter_C26995                             ko00000,ko00001,ko02035
# Ebacter_C77936                                     ko00000,ko02035
# Ebacter_C45587                     ko00000,ko00001,ko02035,ko02044
# Ebacter_C20772                             ko00000,ko00001,ko02035
# Ebacter_C45044                     ko00000,ko02035,ko02044,ko03110
# Ebacter_C87336                             ko00000,ko00001,ko02035
# Ebacter_C91316                             ko00000,ko00001,ko02035
# Ebacter_C63709                             ko00000,ko00001,ko02035
# Ebacter_C26698                             ko00000,ko00001,ko02035
# Ebacter_C73894                             ko00000,ko00001,ko02035
# Ebacter_C20134     ko00000,ko00001,ko00002,ko02000,ko02035,ko02044
# Ebacter_C8728                              ko00000,ko00001,ko02035
# Ebacter_C31523                     ko00000,ko00001,ko02000,ko02035
# Ebacter_C32116                     ko00000,ko00001,ko02000,ko02035
# Ebacter_C42833                             ko00000,ko00001,ko02035
# Ebacter_C39565                     ko00000,ko00001,ko02035,ko02044
# Ebacter_C23423                             ko00000,ko00001,ko02035
# Ebacter_C46083                             ko00000,ko00001,ko02035
# Ebacter_C79052                             ko00000,ko00001,ko02035
# Ebacter_C10828                             ko00000,ko00001,ko02035
# Ebacter_C46082                     ko00000,ko00001,ko02035,ko02044
# Ebacter_C42326             ko00000,ko00001,ko00002,ko02035,ko02044
# Ebacter_C13196             ko00000,ko00001,ko01000,ko02035,ko02044
# Ebacter_C8278                      ko00000,ko00001,ko02035,ko02044
# Ebacter_C79854                             ko00000,ko00001,ko02035
# Ebacter_C5478    ko00000,ko00001,ko00002,ko01000,ko01001,ko0202...
# Ebacter_C32304                             ko00000,ko00001,ko02035
# Ebacter_C82704                     ko00000,ko00001,ko02035,ko02044
# Ebacter_C66693             ko00000,ko00001,ko00002,ko02022,ko02035
# Ebacter_C83806                     ko00000,ko00001,ko02035,ko02044
# Ebacter_C39362                             ko00000,ko00001,ko02035
# Ebacter_C8877                              ko00000,ko00001,ko02035
# Ebacter_C79469                             ko00000,ko00001,ko02035
# Ebacter_C100471                    ko00000,ko00001,ko02035,ko02044
# Ebacter_C30092   ko00000,ko00001,ko00002,ko01000,ko01011,ko0203...
# Ebacter_C4751                      ko00000,ko00001,ko02035,ko02044
# Ebacter_C23562     ko00000,ko00001,ko00002,ko01000,ko02022,ko02035
# Ebacter_C51220                             ko00000,ko00001,ko02035
# Ebacter_C10671                             ko00000,ko00001,ko02035
#
#                                           KEGG_TC CAZy BiGG_Reaction  \
# gene
# Ebacter_C81012                            3.A.6.2    -             -
# Ebacter_C17706                                  -    -             -
# Ebacter_C62234                                  -    -             -
# Ebacter_C74657                                  -    -             -
# Ebacter_C26995                                  -    -             -
# Ebacter_C77936                                  -    -             -
# Ebacter_C45587                            3.A.6.2    -             -
# Ebacter_C20772                                  -    -             -
# Ebacter_C45044                                  -    -             -
# Ebacter_C87336                                  -    -             -
# Ebacter_C91316                                  -    -             -
# Ebacter_C63709                                  -    -             -
# Ebacter_C26698                                  -    -             -
# Ebacter_C73894                                  -    -             -
# Ebacter_C20134   1.A.30.1,3.A.6.1,3.A.6.2,3.A.6.3    -             -
# Ebacter_C8728                                   -    -             -
# Ebacter_C31523                           1.A.30.1    -             -
# Ebacter_C32116                           1.A.30.1    -             -
# Ebacter_C42833                                  -    -             -
# Ebacter_C39565                            3.A.6.2    -             -
# Ebacter_C23423                                  -    -             -
# Ebacter_C46083                                  -    -             -
# Ebacter_C79052                                  -    -             -
# Ebacter_C10828                                  -    -             -
# Ebacter_C46082                                  -    -             -
# Ebacter_C42326            3.A.6.1,3.A.6.2,3.A.6.3    -             -
# Ebacter_C13196                    3.A.6.2,3.A.6.3    -             -
# Ebacter_C8278                     3.A.6.2,3.A.6.3    -             -
# Ebacter_C79854                                  -    -             -
# Ebacter_C5478                                   -    -             -
# Ebacter_C32304                                  -    -             -
# Ebacter_C82704                    3.A.6.2,3.A.6.3    -             -
# Ebacter_C66693                                  -    -             -
# Ebacter_C83806                            3.A.6.2    -             -
# Ebacter_C39362                                  -    -             -
# Ebacter_C8877                                   -    -             -
# Ebacter_C79469                                  -    -             -
# Ebacter_C100471                           3.A.6.2    -             -
# Ebacter_C30092                                  -    -             -
# Ebacter_C4751                     3.A.6.2,3.A.6.3    -             -
# Ebacter_C23562                                  -    -             -
# Ebacter_C51220                                  -    -             -
# Ebacter_C10671                                  -    -             -
#
#                                                         PFAMs
# gene
# Ebacter_C81012                                           FliO
# Ebacter_C17706                      FlaE,Flg_bb_rod,Flg_bbr_C
# Ebacter_C62234                                           FliL
# Ebacter_C74657                                           FlgN
# Ebacter_C26995                           FliG_C,FliG_M,FliG_N
# Ebacter_C77936                                           FlhE
# Ebacter_C45587                                           FliH
# Ebacter_C20772                                           FlgI
# Ebacter_C45044                                  PapD_C,PapD_N
# Ebacter_C87336                                           FlhD
# Ebacter_C91316                                           FliE
# Ebacter_C63709                                           FlgH
# Ebacter_C26698                                   FliM,FliMN_C
# Ebacter_C73894                                           FliJ
# Ebacter_C20134                      Bac_export_1,Bac_export_2
# Ebacter_C8728                            Flg_bb_rod,Flg_bbr_C
# Ebacter_C31523                                 MotB_plug,OmpA
# Ebacter_C32116                                      MotA_ExbB
# Ebacter_C42833                           Flg_bb_rod,Flg_bbr_C
# Ebacter_C39565                                   Bac_export_1
# Ebacter_C23423                                       Flg_hook
# Ebacter_C46083                        FLgD_tudor,FlgD,FlgD_ig
# Ebacter_C79052                                     Flg_bb_rod
# Ebacter_C10828                Flagellin_C,Flagellin_N,FliC_SP
# Ebacter_C46082                                       ChapFlgA
# Ebacter_C42326                                           FliP
# Ebacter_C13196                      ATP-synt_ab,ATP-synt_ab_N
# Ebacter_C8278                           YscJ_FliF,YscJ_FliF_C
# Ebacter_C79854                           Flg_bb_rod,Flg_bbr_C
# Ebacter_C5478    CheW,CheY-binding,H-kinase_dim,HATPase_c,Hpt
# Ebacter_C32304                        Flagellin_C,Flagellin_N
# Ebacter_C82704                                   CheC,FliMN_C
# Ebacter_C66693                                           CheW
# Ebacter_C83806                                           FliO
# Ebacter_C39362                           Flg_bb_rod,Flg_bbr_C
# Ebacter_C8877                             HAMP,MCPsignal,TarH
# Ebacter_C79469                                           FliS
# Ebacter_C100471                                  Bac_export_3
# Ebacter_C30092                    Glucosaminidase,Rod-binding
# Ebacter_C4751                                          FHIPEP
# Ebacter_C23562                    CheB_methylest,Response_reg
# Ebacter_C51220                                           CheZ
# Ebacter_C10671                     Flagellin_IN,FliD_C,FliD_N
#
# [43 rows x 21 columns]

# %%
X = L_binarized[characterized_order].T
links = scipy.cluster.hierarchy.linkage(X, method="ward")


clusters = {x:[x] for x in range(len(X.index))}

for i, (left, right, _, _) in enumerate(links):
    clusters[len(clusters)] = clusters[left] + clusters[right]


def track_split(cluster, clusters, links):
    if len(clusters[cluster]) == 1:
        return cluster

    row = cluster - len(links) - 1
    left_child = int(links[row][0])
    right_child = int(links[row][1])
    
    return {cluster:{left_child:track_split(left_child, clusters, links), right_child:track_split(right_child, clusters, links)}}


split_tree = track_split(max(clusters.keys()), clusters, links)

# %%
def get_gene_sets(df_genes, splits, clusters, value):
    cluster_members = clusters[value]
    cluster_size = len(cluster_members)

    df_array = df_genes.values
    member_cols = np.array(cluster_members)
    other_cols = np.array([x for x in range(df_genes.shape[1]) if x not in member_cols])

    if other_cols.size == 0:  # Handle edge case
        unique_genes = (df_array[:, member_cols] == 1).all(axis=1)
        shared_genes = (df_array[:, member_cols] == 1).any(axis=1)
        return(unique_genes.sum(), shared_genes.sum())
    
    unique_genes = (df_array[:, member_cols] == 1).all(axis=1) & (df_array[:, other_cols] == 0).all(axis=1)
    shared_genes = (df_array[:, member_cols] == 1).any(axis=1) & (df_array[:, other_cols] == 0).all(axis=1)
    
    return (unique_genes.sum(), shared_genes.sum())


gene_P = L_binarized[characterized_order]
gene_P.columns = list(range(len(gene_P.columns)))


gene_values = pd.DataFrame(index = clusters.keys(), columns = ['unique_genes', 'shared_genes'])

for cluster in tqdm(list(clusters.keys())):
    gene_values.loc[cluster] = get_gene_sets(gene_P, split_tree, clusters, cluster)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %%
gene_values
# Out:
#    unique_genes shared_genes
# 0            29           29
# 1            38           38
# 2            94           94
# 3             1            1
# 4           109          109
# 5           139          139
# 6           102          102
# 7            11           11
# 8           108          108
# 9            62           62
# 10           17           17
# 11           40           40
# 12           14           14
# 13           37           37
# 14           35           35
# 15           74          187
# 16           61          171
# 17           14           81
# 18           50          341
# 19           34          204
# 20           28          100
# 21           15           72
# 22           17          511
# 23           29          419
# 24            9          143
# 25            6          352
# 26          162         1273
# 27           56         1024
# 28          158         3680
